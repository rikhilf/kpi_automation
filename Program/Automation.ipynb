# %% [markdown]
# Auto-reload data files

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
import string

from numpy import array


file_name: str = "september_data.csv"

data = pd.read_csv(file_name)

needed_columns = data[["StartDate", "EndDate", "Q1", "Q2", "Q3", "Q4", "PMO - Led", "Quarter"]].copy()

needed_columns
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/Ne...
# 2                                 2020-11-11 15:48:31
# 3                                 2020-11-13 14:41:45
# 4                                 2020-11-13 13:27:16
# ..                                                ...
# 77                                2022-06-16 08:25:25
# 78                                2022-06-22 10:28:16
# 79                                2022-08-12 09:51:44
# 80                                2022-08-14 09:17:11
# 81                                2022-08-29 07:00:37
#
#                                               EndDate  \
# 0                                            End Date
# 1   {"ImportId":"endDate","timeZone":"America/New_...
# 2                                 2020-11-11 15:50:30
# 3                                 2020-11-13 14:42:06
# ...

# %%
pmo_led = data["PMO - Led"] == "Yes"
non_pmo_led = data["PMO - Led"] == "No"
year = list()
i: int = 0
while i < len(data):
    year.append(data["EndDate"][i][0:4])
    i += 1
year_list: list[str] = list()
month_list: list[str] = list()

# i: int = 0
# for item in year:
#     year_list.append((item[2] + item[3]))
#     month_list.append((item[5] + item[6]))
#     i += 1


# needed_columns["year"] = year_list
# needed_columns.loc[0, 3] = year_list
# needed_columns["month"] = month_list

needed_columns
year
# Out:
# ['End ',
#  '{"Im',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022']

# %%
# for item in year:
#     if "20" in item:
#             year_list.append(item[2] + item[3])
#             month_list.append(item[5] + item[6])
# print(year_list)
# print(month_list)

# %%
needed_year: int = input("What is the needed year? (Enter in format 20XX")
filtered_by_year = 
needed_quarter: str = input("What is your target quarter? (Type in format QX")
pmo_led_string: str = input("PMO-Led? (Enter 'Y' (yes) 'N' (no) or 'B' (both)): ")

while pmo_led_string != "Y" and pmo_led_string != "N" and pmo_led_string != "B":
    pmo_led_string: str = input("PMO-Led? (Please enter 'Y' or 'N'): ")
if pmo_led_string == "Y":
    pmo_selection = data["PMO - Led"] == "Yes"
    filtered_by_pmo = needed_columns[pmo_selection]
elif pmo_led_string == "N":
    pmo_selection = data["PMO - Led"] == "No"
    filtered_by_pmo = needed_columns[pmo_selection]
elif pmo_led_string == "B":
    filtered_by_pmo = needed_columns



# if needed_year in year_list:
#     quarter_selection: list[bool] = needed_quarter == data["Quarter"]
#     filtered_by_fy = filtered_by_pmo[quarter_selection]

# filtered_by_fy
filtered_by_pmo
# Out:
#               StartDate              EndDate              Q1  \
# 25  2020-12-18 12:26:00  2020-12-18 12:36:01  Strongly agree
# 30  2021-02-10 14:06:46  2021-02-10 14:07:20  Strongly agree
# 32  2021-03-10 09:12:13  2021-03-10 09:17:28  Strongly agree
# 33  2021-03-11 14:19:45  2021-03-11 14:25:54  Strongly agree
# 34  2021-03-17 12:18:13  2021-03-17 12:19:26  Strongly agree
# 35  2021-03-18 15:29:24  2021-03-18 15:29:39  Strongly agree
# 36  2021-03-26 10:30:49  2021-03-26 10:31:07  Strongly agree
# 37  2021-04-22 10:54:44  2021-04-22 10:56:07  Strongly agree
# 38  2021-04-30 15:13:06  2021-04-30 15:14:07  Strongly agree
# 39  2021-05-05 09:56:24  2021-05-05 09:56:52  Strongly agree
# 40  2021-05-07 11:28:24  2021-05-12 10:37:43  Strongly agree
# 44  2021-06-29 17:37:35  2021-06-29 17:37:57  Strongly agree
# 45  2021-07-20 09:20:16  2021-07-20 09:21:19  Strongly agree
# 46  2021-07-28 16:01:26  2021-07-28 16:06:42  Strongly agree
# ...

# %%
filtered_by_date = filtered_by_pmo
needed_columns["Year"] = year

i: int = 0

needed_columns
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/Ne...
# 2                                 2020-11-11 15:48:31
# 3                                 2020-11-13 14:41:45
# 4                                 2020-11-13 13:27:16
# ..                                                ...
# 77                                2022-06-16 08:25:25
# 78                                2022-06-22 10:28:16
# 79                                2022-08-12 09:51:44
# 80                                2022-08-14 09:17:11
# 81                                2022-08-29 07:00:37
#
#                                               EndDate  \
# 0                                            End Date
# 1   {"ImportId":"endDate","timeZone":"America/New_...
# 2                                 2020-11-11 15:50:30
# 3                                 2020-11-13 14:42:06
# ...

# %%
Q1 = df["Q1"]
q1_sum: int = 0
for item in Q1:
    q1_sum += item

Q2 = df["Q2"]
q2_sum: int = 0
for item in Q2:
    q2_sum += item

Q3 = df["Q3"]
q3_sum: int = 0
for item in Q3:
    q3_sum += item

def calculation_1(df):
    
    
   

def calculation_2(df):
    
    Q1 = df["Q1"]
    q1_sum: int = 0
    for item in Q1:
        q1_sum += item
    
    Q2 = df["Q2"]
    q2_sum: int = 0
    for item in Q2:
        q2_sum += item

    Q3 = df["Q3"]
    q3_sum: int = 0
    for item in Q3:
        q3_sum += item


def calculation_3(df):
    
    Q1 = df["Q1"]
    q1_sum: int = 0
    for item in Q1:
        q1_sum += item
    
    Q2 = df["Q2"]
    q2_sum: int = 0
    for item in Q2:
        q2_sum += item

    Q3 = df["Q3"]
    q3_sum: int = 0
    for item in Q3:
        q3_sum += item
# Out:
#   Input In [41]
#     def calculation_2(df):
#     ^
# IndentationError: expected an indented block after function definition on line 16

# %%
answered: bool = False
while not answered:
    response: str = input("What are you calculating? 1: x 2: y 3: z")
    if response == "1" or response == "2" or response == "3":
        answered = True

if response == "1":
    calculation_1(filtered_by_pmo)
elif response == "2":
    calculation_2(filtered_by_pmo)
elif response == "3":
    calculation_3(filtered_by_pmo)
