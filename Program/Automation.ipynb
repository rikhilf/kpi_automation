# %% [markdown]
# Auto-reload data files

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
data = pd.read_csv("qualtrics_survey_july.csv")

needed_columns = data[["Q1", "Q2", "Q3", "Q4", "PMO - Led", "Quarter"]]

needed_columns
# Out:
#                                                    Q1  ...                           Quarter
# 0   Based on your understanding of the project, th...  ...                           Quarter
# 1                                 {"ImportId":"QID1"}  ...  {"ImportId":"Quarte_CEDhf2qyjk"}
# 2                                      Somewhat agree  ...                      FY2020-21 Q2
# 3                                      Somewhat agree  ...                      FY2020-21 Q2
# 4                                      Strongly agree  ...                      FY2020-21 Q2
# ..                                                ...  ...                               ...
# 75                                     Strongly agree  ...                      FY2021-22 Q4
# 76                                     Strongly agree  ...                      FY2021-22 Q4
# 77                                     Strongly agree  ...                      FY2022-23 Q1
# 78                                     Strongly agree  ...                      FY2022-23 Q1
# 79                                     Strongly agree  ...                      FY2022-23 Q1
#
# [80 rows x 6 columns]

# %%
pmo_led = data["PMO - Led"] == "Yes"
non_pmo_led = data["PMO - Led"] == "No"
quarter = data["Quarter"]
quarter_list: list[str] = list()

for item in quarter:
    if "FY" in item:
        if item not in quarter_list:
            quarter_list.append(item)
print(quarter_list)
# Out:
# ['FY2020-21 Q2', 'FY2020-21 Q3', 'FY2020-21 Q1', 'FY2019-20 Q3', 'FY2020-21 Q4', 'FY2021-22 Q1', 'FY2021-22 Q2', 'FY2021-22 Q3', 'FY2021-22 Q4', 'FY2022-23 Q1']

# %%
needed_quarter: str = input("What is your target quarter? (Type in format FY20XX-XX QX): ")

if needed_quarter in quarter_list:
    quarter_selection: list[bool] = needed_quarter == data["Quarter"]
    filtered_by_fy = needed_columns[quarter_selection]

# %%
def calculation_1(df):
    
    Q1 = df["Q1"]
    q1_sum: int = 0
    for item in Q1:
        q1_sum += item
    
    Q2 = df["Q2"]
    q2_sum: int = 0
    for item in Q2:
        q2_sum += item

    Q3 = df["Q3"]
    q3_sum: int = 0
    for item in Q3:
        q3_sum += item

def calculation_2(df):
    
    Q1 = df["Q1"]
    q1_sum: int = 0
    for item in Q1:
        q1_sum += item
    
    Q2 = df["Q2"]
    q2_sum: int = 0
    for item in Q2:
        q2_sum += item

    Q3 = df["Q3"]
    q3_sum: int = 0
    for item in Q3:
        q3_sum += item


def calculation_3(df):
    
    Q1 = df["Q1"]
    q1_sum: int = 0
    for item in Q1:
        q1_sum += item
    
    Q2 = df["Q2"]
    q2_sum: int = 0
    for item in Q2:
        q2_sum += item

    Q3 = df["Q3"]
    q3_sum: int = 0
    for item in Q3:
        q3_sum += item

# %%
answered: bool = False
while not answered:
    response: str = input("What are you calculating? 1: x 2: y 3: z")
    if response == "1" or response == "2" or response == "3":
        answered = True

if response == "1":
    calculation_1(filtered_by_fy)
elif response == "2":
    calculation_2(filtered_by_fy)
elif response == "3":
    calculation_3(filtered_by_fy)
